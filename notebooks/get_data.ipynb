# %%
import requests
import pandas as pd
import os

# %%
endpoint = 'https://data.lacity.org/resource/2nrs-mtv8.json'

# %%
response = requests.get(url=endpoint,
                        headers={"Accept":"application/json",
                                 "X-App-Token":os.getenv('chicago_app_token')},
                        params={'$where':"date_occ between '2022-01-01T00:00:00' and '2022-12-31T23:59:59'",
                                '$limit':'500000'},
                        auth=(os.getenv('chicago_key_id'),os.getenv('chicago_key_secret')))

# %%
data = pd.json_normalize(data=response.json())

# %%
data.head()
# Out:
#        dr_no                date_rptd                 date_occ time_occ area  \
# 0  221007028  2022-03-22T00:00:00.000  2022-01-01T00:00:00.000     0435   10
# 1  220804319  2022-01-09T00:00:00.000  2022-01-01T00:00:00.000     1200   08
# 2  221804053  2022-01-01T00:00:00.000  2022-01-01T00:00:00.000     2105   18
# 3  230508709  2023-05-13T00:00:00.000  2022-01-01T00:00:00.000     0001   05
# 4  231608143  2023-05-11T00:00:00.000  2022-01-01T00:00:00.000     0001   16
#
#      area_name rpt_dist_no part_1_2 crm_cd                     crm_cd_desc  \
# 0  West Valley        1067        2    354               THEFT OF IDENTITY
# 1      West LA        0832        1    310                        BURGLARY
# 2    Southeast        1863        1    330           BURGLARY FROM VEHICLE
# 3       Harbor        0513        2    354               THEFT OF IDENTITY
# 4     Foothill        1641        2    813  CHILD ANNOYING (17YRS & UNDER)
#
# ...

# %%
data.to_csv(path_or_buf='../data/raw/raw_data.csv',
            index=False)
