# %%
import requests
import pandas as pd
import os

# %%
endpoint = 'https://data.lacity.org/resource/2nrs-mtv8.json'

# %%
response = requests.get(url=endpoint,
             headers={"Accept":"application/json",
                      "X-App-Token":os.getenv('chicago_app_token')},
             params={'$where':"date_occ between '2022-01-10T00:00:00' and '2022-12-31T23:59:59'"},
             auth=(os.getenv('chicago_key_id'),os.getenv('chicago_key_secret'))
)

# %%
data = pd.json_normalize(data=response.json())

# %%
data.head()
# Out:
#        dr_no                date_rptd                 date_occ time_occ area  \
# 0  221104665  2022-01-18T00:00:00.000  2022-01-10T00:00:00.000     0830   11
# 1  220804331  2022-01-11T00:00:00.000  2022-01-10T00:00:00.000     1240   08
# 2  222104332  2022-01-11T00:00:00.000  2022-01-10T00:00:00.000     1200   21
# 3  220104769  2022-01-14T00:00:00.000  2022-01-10T00:00:00.000     2000   01
# 4  221505066  2022-01-24T00:00:00.000  2022-01-10T00:00:00.000     0030   15
#
#      area_name rpt_dist_no part_1_2 crm_cd  \
# 0    Northeast        1142        1    331
# 1      West LA        0848        1    510
# 2      Topanga        2102        1    310
# 3      Central        0156        1    210
# 4  N Hollywood        1535        2    354
#
#                                          crm_cd_desc  ...  status_desc  \
# 0  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...  ...  Invest Cont
# 1                                   VEHICLE - STOLEN  ...  Adult Other
# 2                                           BURGLARY  ...  Invest Cont
# 3                                            ROBBERY  ...  Invest Cont
# 4                                  THEFT OF IDENTITY  ...  Invest Cont
#
#   crm_cd_1                                  location      lat        lon  \
# 0      331   2100    RODNEY                       DR    34.11  -118.2893
# 1      510           SHENANDOAH                   ST  34.0536  -118.4115
# 2      310   8800    CHATLAKE                     DR  34.2298  -118.6472
# 3      210           5TH                          ST  34.0446   -118.245
# 4      354  11400    EMELITA                      ST  34.1767   -118.379
#
#                       cross_street weapon_used_cd  \
# 0                              NaN            NaN
# 1  OLYMPIC                      BL            NaN
# 2                              NaN            NaN
# 3                             WALL            200
# 4                              NaN            NaN
#
#                         weapon_desc crm_cd_2 crm_cd_3
# 0                               NaN      NaN      NaN
# 1                               NaN      NaN      NaN
# 2                               NaN      NaN      NaN
# 3  KNIFE WITH BLADE 6INCHES OR LESS      NaN      NaN
# 4                               NaN      NaN      NaN
#
# [5 rows x 27 columns]
